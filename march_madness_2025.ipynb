# %% [markdown]
# # functions and imports

# %%
from ollama import chat

def stream_function(question):
    stream = chat(
        model='llama3.2:1b',
        messages=[{'role': 'user', 'content': question}],
        stream=True,
    )

    for chunk in stream:
        print(chunk['message']['content'], end='', flush=True)

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

# Initialize the Kaggle API
api = KaggleApi()
api.authenticate()

# Define the dataset path (this is the URL path of the dataset on Kaggle)
dataset_name = "jonathanpilafas/2024-march-madness-statistical-analysis"


# Download the dataset to your current working directory
api.dataset_download_files(dataset_name, path='.', unzip=True)

print("Dataset downloaded successfully!")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jonathanpilafas/2024-march-madness-statistical-analysis
# Dataset downloaded successfully!

# %%
import pandas as pd
import zipfile
import re

# Create a dictionary to store your dataframes
dataframes = {}

# Your zip filename

match = re.search(r'/(?<=/)(.*)', dataset_name)
if match:
    result = match.group(1)
zip_filename = result + '.zip'

with zipfile.ZipFile(zip_filename, 'r') as zip_file:
    # Show what files are in the ZIP
    print("Files in the ZIP:", zip_file.namelist())
    
    # Read each CSV file from the ZIP into a DataFrame
    for filename in zip_file.namelist():
        if filename.endswith('.csv'):
            # Create a clean key by replacing spaces and special characters
            key = filename.replace('.csv', '').replace(' _ ', '_').replace(' ', '_')
            
            # Read CSV with low_memory=False to handle mixed types warning
            dataframes[key] = pd.read_csv(zip_file.open(filename), low_memory=False)
            print(f"Loaded: {filename}")
# Out:
# Files in the ZIP: ['DEV _ March Madness.csv', 'INT _ KenPom _ Defense.csv', 'INT _ KenPom _ Efficiency.csv', 'INT _ KenPom _ Height.csv', 'INT _ KenPom _ Miscellaneous Team Stats.csv', 'INT _ KenPom _ Offense.csv', 'INT _ KenPom _ Point Distribution.csv', 'INT _ KenPom _ Summary.csv', 'REF _ 2024 Post-Season Tournament Teams.csv', 'REF _ Current NCAAM Coaches.csv']
# Loaded: DEV _ March Madness.csv
# Loaded: INT _ KenPom _ Defense.csv
# Loaded: INT _ KenPom _ Efficiency.csv
# Loaded: INT _ KenPom _ Height.csv
# Loaded: INT _ KenPom _ Miscellaneous Team Stats.csv
# Loaded: INT _ KenPom _ Offense.csv
# Loaded: INT _ KenPom _ Point Distribution.csv
# Loaded: INT _ KenPom _ Summary.csv
# Loaded: REF _ 2024 Post-Season Tournament Teams.csv
# Loaded: REF _ Current NCAAM Coaches.csv

# %%
# Create individual variables for easier access
march_madness = dataframes['DEV_March_Madness']
kenpom_defense = dataframes['INT_KenPom_Defense']
kenpom_efficiency = dataframes['INT_KenPom_Efficiency']
kenpom_height = dataframes['INT_KenPom_Height']
kenpom_misc_stats = dataframes['INT_KenPom_Miscellaneous_Team_Stats']
kenpom_offense = dataframes['INT_KenPom_Offense']
kenpom_point_dist = dataframes['INT_KenPom_Point_Distribution']
kenpom_summary = dataframes['INT_KenPom_Summary']
tournament_teams = dataframes['REF_2024_Post-Season_Tournament_Teams']
current_coaches = dataframes['REF_Current_NCAAM_Coaches']

# Show what dataframes were created with more detail
print("\nAvailable dataframes:")
for key, df in dataframes.items():
    print(f"- {key}:")
    print(f"  Rows: {df.shape[0]}, Columns: {df.shape[1]}")
    print(f"  Memory usage: {df.memory_usage().sum() / 1024**2:.2f} MB")
# Out:
# Available dataframes:
# - DEV_March_Madness:
#   Rows: 8314, Columns: 147
#   Memory usage: 9.32 MB
# - INT_KenPom_Defense:
#   Rows: 9268, Columns: 10
#   Memory usage: 0.71 MB
# - INT_KenPom_Efficiency:
#   Rows: 9268, Columns: 19
#   Memory usage: 1.34 MB
# - INT_KenPom_Height:
#   Rows: 6670, Columns: 50
#   Memory usage: 2.54 MB
# - INT_KenPom_Miscellaneous_Team_Stats:
#   Rows: 8314, Columns: 35
#   Memory usage: 2.22 MB
# - INT_KenPom_Offense:
#   Rows: 9268, Columns: 10
#   Memory usage: 0.71 MB
# - INT_KenPom_Point_Distribution:
#   Rows: 9269, Columns: 14
#   Memory usage: 0.99 MB
# - INT_KenPom_Summary:
#   Rows: 9268, Columns: 16
#   Memory usage: 1.13 MB
# - REF_2024_Post-Season_Tournament_Teams:
#   Rows: 131, Columns: 6
#   Memory usage: 0.01 MB
# - REF_Current_NCAAM_Coaches:
#   Rows: 364, Columns: 4
#   Memory usage: 0.01 MB

# %%
for name, df in dataframes.items():
    print(f"{name} - Shape: {df.shape}")
    print(df.head(), "\n")
# Out:
# DEV_March_Madness - Shape: (8314, 147)
#    Season Short Conference Name  Adjusted Temo  Adjusted Tempo Rank  \
# 0    2015                   SEC           62.4                  274
# 1    2021                   WCC           73.8                    7
# 2    2024                    BE           64.6                  330
# 3    2025                   SEC           67.8                  143
# 4    2025                   ACC           65.3                  268
#
#    Raw Tempo  Raw Tempo Rank  Adjusted Offensive Efficiency  \
# 0       63.8             242                          121.3
# 1       74.3              14                          126.4
# 2       66.0             305                          127.5
# 3       68.6             164                          130.4
# 4       66.4             276                          124.0
#
#    Adjusted Offensive Efficiency Rank  Raw Offensive Efficiency  \
# 0                                   6                     115.5
# 1                                   1                     121.9
# 2                                   1                     123.0
# 3                                   1                     123.0
# 4                                   5                     121.2
#
#    Raw Offensive Efficiency Rank  ...  Current Coach     Full Team Name  \
# 0                              9  ...      Mark Pope  Kentucky Wildcats
# 1                              1  ...       Mark Few   Gonzaga Bulldogs
# 2                              1  ...     Dan Hurley      UConn Huskies
# 3                              1  ...    Bruce Pearl      Auburn Tigers
# 4                              3  ...    Jon Scheyer   Duke Blue Devils
#
#       Since  Active Coaching Length  Active Coaching Length Index  \
# 0  202425.0                 0 years                           1.0
# 1  199900.0                25 years                          26.0
# 2  201819.0                 6 years                           7.0
# 3  201415.0                10 years                          11.0
# 4  202223.0                 2 years                           3.0
#
#                               Seed                           Region  \
# 0  Not In a Post-Season Tournament  Not In a Post-Season Tournament
# 1  Not In a Post-Season Tournament  Not In a Post-Season Tournament
# 2                                1                             East
# 3  Not In a Post-Season Tournament  Not In a Post-Season Tournament
# 4  Not In a Post-Season Tournament  Not In a Post-Season Tournament
#
#    Correct Team Name?           Post-Season Tournament  \
# 0                 NaN  Not In a Post-Season Tournament
# 1                 NaN  Not In a Post-Season Tournament
# 2               UConn                    March Madness
# 3                 NaN  Not In a Post-Season Tournament
# 4                 NaN  Not In a Post-Season Tournament
#
#    Post-Season Tournament Sorting Index
# 0                                     5
# 1                                     5
# 2                                     1
# 3                                     5
# 4                                     5
#
# [5 rows x 147 columns]
#
# INT_KenPom_Defense - Shape: (9268, 10)
#    Season           TeamName     eFGPct  RankeFGPct      TOPct  RankTOPct  \
# 0    2019  Abilene Christian  49.837557         132  23.276634          9
# 1    2019          Air Force  53.549120         300  17.785955        221
# 2    2019              Akron  45.452024          13  19.058349        134
# 3    2019            Alabama  48.925256          90  16.878700        274
# 4    2019        Alabama A&M  53.670520         308  20.949713         44
#
#        ORPct  RankORPct     FTRate  RankFTRate
# 0  28.481013        188  38.271605         299
# 1  24.137931         18  28.563316          67
# 2  29.873418        251  30.560177         117
# 3  27.977618        165  29.555447          87
# 4  31.866029        305  38.843931         308
#
# INT_KenPom_Efficiency - Shape: (9268, 19)
#    Season         Team Conference  Adjusted Temo  Adjusted Tempo Rank  \
# 0    2002    Air Force        MWC           54.2                  327
# 1    2002        Akron        MAC           65.6                  251
# 2    2002      Alabama        SEC           68.0                  170
# 3    2002  Alabama A&M       SWAC           79.0                    1
# 4    2002  Alabama St.       SWAC           63.1                  305
#
#    Raw Tempo  Raw Tempo Rank  Adjusted Offensive Efficiency  \
# 0       55.8             327                          103.8
# 1       66.7             260                          105.2
# 2       69.8             171                          114.0
# 3       81.6               1                           92.2
# 4       68.2             223                           90.1
#
#    Adjusted Offensive Efficiency Rank  Raw Offensive Efficiency  \
# 0                                 149                      99.5
# 1                                 130                     102.7
# 2                                  24                     108.2
# 3                                 304                      97.8
# 4                                 312                      94.9
#
#    Raw Offensive Efficiency Rank  Adjusted Defensive Efficiency  \
# 0                            190                          105.5
# 1                            128                          111.2
# 2                             42                           95.3
# 3                            220                          101.7
# 4                            264                          102.7
#
#    Adjusted Defensive Efficiency Rank  Raw Defensive Efficiency  \
# 0                                 214                     106.8
# 1                                 295                     110.8
# 2                                  32                      96.0
# 3                                 136                      90.7
# 4                                 159                      94.0
#
#    Raw Defensive Efficiency Rank  Avg Possession Length (Offense)  \
# 0                            283                              NaN
# 1                            313                              NaN
# 2                             56                              NaN
# 3                              4                              NaN
# 4                             26                              NaN
#
#    Avg Possession Length (Offense) Rank  Avg Possession Length (Defense)  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
#
#    Avg Possession Length (Defense) Rank
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
# INT_KenPom_Height - Shape: (6670, 50)
#    Season     TeamName  AvgHeight  RankAvgHeight  CenterHeight  \
# 0    2011    Air Force      77.34             60         -0.83
# 1    2011        Akron      76.56            167          1.37
# 2    2011      Alabama      76.45            187         -0.46
# 3    2011  Alabama A&M      75.14            324         -0.92
# 4    2011  Alabama St.      76.02            247         -1.16
#
#    RankCenterHeight  PFHeight  RankPFHeight  SFHeight  RankSFHeight  ...  \
# 0               262     -0.17           207      0.96            64  ...
# 1                34     -0.16           174     -0.04           173  ...
# 2               228     -0.16           176     -0.49           236  ...
# 3               272     -1.17           303     -0.06           208  ...
# 4               296     -1.86           330     -0.04           200  ...
#
#    CenterDR  RankCenterDR   PFDR  RankPFDR   SFDR  RankSFDR   SGDR  RankSGDR  \
# 0     20.87           318  18.29       337  20.36       134  22.49         4
# 1     24.33           238  27.34        76  20.22       143  14.35       229
# 2     27.44           137  26.62        94  17.34       259  13.25       273
# 3     22.45           285  24.67       166  22.91        53  15.88       146
# 4     24.32           239  23.65       200  22.17        68  18.52        49
#
#     PGDR  RankPGDR
# 0  18.00        21
# 1  13.77       156
# 2  15.35        83
# 3  14.09       139
# 4  11.33       277
#
# [5 rows x 50 columns]
#
# INT_KenPom_Miscellaneous_Team_Stats - Shape: (8314, 35)
#    Season           TeamName     FG2Pct  RankFG2Pct     FG3Pct  RankFG3Pct  \
# 0    2017  Abilene Christian  50.700935         112  37.106918          75
# 1    2017          Air Force  46.889508         276  36.283186         110
# 2    2017              Akron  55.009823          16  36.781609          91
# 3    2017            Alabama  48.666667         199  31.690141         312
# 4    2017        Alabama A&M  45.479204         307  27.352298         350
#
#        FTPct  RankFTPct   BlockPct  RankBlockPct  ...  RankOppARate   StlRate  \
# 0  64.224138        336   8.098592           216  ...           248  0.101302
# 1  71.646341        127   5.957447           322  ...           328  0.084611
# 2  68.070652        255   8.327082           205  ...            26  0.080509
# 3  65.281501        320  11.547912            60  ...             9  0.086023
# 4  66.612378        289   4.537522           350  ...           149  0.053332
#
#    RankStlRate  OppStlRate  RankOppStlRate        DFP  NSTRate  RankNSTRate  \
# 0           58    0.087409             178   9.383294      NaN          NaN
# 1          187    0.090159             223  -8.700873      NaN          NaN
# 2          218    0.086380             168   9.906687      NaN          NaN
# 3          181    0.092475             252  14.490882      NaN          NaN
# 4          350    0.105629             332   4.681746      NaN          NaN
#
#    OppNSTRate  RankOppNSTRate
# 0         NaN             NaN
# 1         NaN             NaN
# 2         NaN             NaN
# 3         NaN             NaN
# 4         NaN             NaN
#
# [5 rows x 35 columns]
#
# INT_KenPom_Offense - Shape: (9268, 10)
#    Season           TeamName     eFGPct  RankeFGPct      TOPct  RankTOPct  \
# 0    2020  Abilene Christian  49.636724         174  20.572064        288
# 1    2020          Air Force  52.868852          38  18.071161        117
# 2    2020              Akron  51.719976          72  17.949238        108
# 3    2020            Alabama  52.171691          61  19.196561        206
# 4    2020        Alabama A&M  42.443544         351  18.780238        171
#
#        ORPct  RankORPct     FTRate  RankFTRate
# 0  28.799150        147  41.083223          13
# 1  22.504892        322  35.011710         112
# 2  27.353816        195  35.546168         101
# 3  29.901153        114  36.842105          69
# 4  24.913793        275  32.657788         173
#
# INT_KenPom_Point_Distribution - Shape: (9269, 14)
#    Season      TeamName    OffFT  RankOffFT  Off2PtFG  RankOff2PtFG  Off3PtFG  \
# 0    2016  North Dakota  20.9292        151   53.2251            85   25.8457
# 1    2016           UAB  18.1928        287   52.5301            97   29.2771
# 2    2016      Delaware  24.1692         23   50.4532           171   25.3776
# 3    2016    Valparaiso  20.0382        203   47.0363           272   32.9254
# 4    2016  Jacksonville  17.3747        322   48.6874           236   33.9379
#
#    RankOff3PtFG    DefFT  RankDefFT  Def2PtFG  RankDef2PtFG  Def3PtFG  \
# 0           261  19.1284        250   49.0826           218   31.7890
# 1           172  17.5439        298   52.4561            87   30.0000
# 2           273  17.8855        288   42.9956           342   39.1189
# 3            83  22.3115         76   48.9067           223   28.7818
# 4            60  17.2461        307   48.3074           252   34.4465
#
#    RankDef3PtFG
# 0            76
# 1           147
# 2             2
# 3           201
# 4            23
#
# INT_KenPom_Summary - Shape: (9268, 16)
#    Season           TeamName    Tempo  RankTempo  AdjTempo  RankAdjTempo  \
# 0    2020  Abilene Christian  70.4017        105   68.4092           172
# 1    2020          Air Force  68.9032        183   68.7757           147
# 2    2020              Akron  70.1211        118   69.4330           110
# 3    2020            Alabama  76.0855          4   74.7606             4
# 4    2020        Alabama A&M  69.6460        137   67.7433           213
#
#          OE  RankOE     AdjOE  RankAdjOE        DE  RankDE     AdjDE  \
# 0  101.4500     159   99.0562        239   96.1085      67  100.1980
# 1  104.9150      89  107.7850         76  109.9970     332  110.2730
# 2  106.7760      58  108.4760         66   95.6119      57   98.9396
# 3  105.9970      71  110.9690         37  102.1720     221   99.4710
# 4   88.2169     347   87.9342        348  101.9150     216  108.1540
#
#    RankAdjDE     AdjEM  RankAdjEM
# 0        126  -1.14144        184
# 1        316  -2.48752        197
# 2        103   9.53601         82
# 3        114  11.49840         60
# 4        297 -20.21960        343
#
# REF_2024_Post-Season_Tournament_Teams - Shape: (131, 6)
#        Team Name  Seed   Region Correct Team Name? Post-Season Tournament  \
# 0         Purdue     1  Midwest             Purdue          March Madness
# 1  Montana State    16  Midwest      Montana State          March Madness
# 2      Grambling    16  Midwest          Grambling          March Madness
# 3     Utah State     8  Midwest         Utah State          March Madness
# 4            TCU     9  Midwest                TCU          March Madness
#
#    Post-Season Tournament Sorting Index
# 0                                     1
# 1                                     1
# 2                                     1
# 3                                     1
# 4                                     1
#
# REF_Current_NCAAM_Coaches - Shape: (364, 4)
#       Current Coach                        Team   Since          Join Team
# 0     Brette Tanner  Abilene Christian Wildcats  202122  Abilene Christian
# 1         Joe Scott           Air Force Falcons  202021          Air Force
# 2        John Groce                  Akron Zips  201718              Akron
# 3         Nate Oats        Alabama Crimson Tide  201920            Alabama
# 4  Otis Hughley Jr.        Alabama A&M Bulldogs  202223        Alabama A&M

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # March Madness Historical Dataset, Model Selection
#
# Model Selection:
# - Season (Last 6 years)
# - Adjusted Tempo (Ranked offensive field goal efficiency percentage)
#     -Should create a YoY%
# -Adjusted Tempo Rank
#     -Offensive turnover percentage

# %%
march_madness[(march_madness['Mapped ESPN Team Name']=='Kentucky') & (march_madness['Season'] >=2020)]
# Out:
#       Season Short Conference Name  Adjusted Temo  Adjusted Tempo Rank  \
# 141     2022                   SEC           67.5                  150
# 288     2025                   SEC           70.5                   38
# 535     2024                   SEC           72.7                   12
# 679     2020                   SEC           67.7                  215
# 705     2023                   SEC           65.8                  256
# 1012    2021                   SEC           68.1                  181
#
#       Raw Tempo  Raw Tempo Rank  Adjusted Offensive Efficiency  \
# 141        69.3             105                          120.0
# 288        72.5              22                          124.7
# 535        73.9               8                          122.2
# 679        68.5             212                          112.7
# 705        66.8             238                          116.2
# 1012       70.0             132                          108.0
#
#       Adjusted Offensive Efficiency Rank  Raw Offensive Efficiency  \
# 141                                    5                     114.1
# 288                                    3                     119.3
# 535                                    7                     118.9
# 679                                   24                     108.0
# 705                                   17                     111.0
# 1012                                  84                      99.7
#
#       Raw Offensive Efficiency Rank  Adjusted Defensive Efficiency  \
# 141                               9                           94.3
# 288                               9                          102.1
# 535                               5                          102.9
# 679                              37                           95.1
# 705                              26                           98.8
# 1012                            198                           93.1
#
#       Adjusted Defensive Efficiency Rank  Raw Defensive Efficiency  \
# 141                                   36                      95.9
# 288                                   89                     105.1
# 535                                  109                     106.4
# 679                                   52                      96.2
# 705                                   68                     100.9
# 1012                                  35                      99.4
#
#       Raw Defensive Efficiency Rank  Avg Possession Length (Offense)  \
# 141                              41                             16.9
# 288                             167                             16.0
# 535                             217                             15.6
# 679                              70                             17.4
# 705                             114                             17.6
# 1012                            113                             17.1
#
#       Avg Possession Length (Offense) Rank  Avg Possession Length (Defense)  \
# 141                                   89.0                             17.7
# 288                                   39.0                             17.1
# 535                                   18.0                             17.1
# 679                                  183.0                             17.7
# 705                                  181.0                             18.1
# 1012                                 151.0                             17.2
#
#       Avg Possession Length (Defense) Rank     eFGPct  RankeFGPct      TOPct  \
# 141                                  206.0  53.116214          44  16.653579
# 288                                   81.0  56.508653          18  14.626303
# 535                                   71.0  57.152908           5  14.274418
# 679                                  251.0  50.696460         123  18.093201
# 705                                  299.0  50.635697         178  17.485383
# 1012                                 147.0  47.086721         289  19.756581
#
#       RankTOPct      ORPct  RankORPct     FTRate  RankFTRate      OffFT  \
# 141          61  37.671233          4  28.022493         248  16.068123
# 288          24  30.860927        163  34.161023         147  17.968323
# 535          26  28.894691        174  30.440901         246  17.052417
# 679         122  30.832477         81  40.800929          18  24.273949
# 705         127  39.202658          1  31.931540         162  18.206951
# 1012        217  32.644178         41  34.485095          90  21.067575
#
#       RankOffFT   Off2PtFG  RankOff2PtFG   Off3PtFG  RankOff3PtFG      DefFT  \
# 141         278  60.940392             3  22.991485           350  16.349978
# 288         244  46.968869           258  35.062807            92  17.932752
# 535         281  49.557522           219  33.390061           100  19.429658
# 679           3  55.309926            51  20.416125           349  19.570522
# 705         183  56.556082            30  25.236967           323  18.611714
# 1012         47  51.675185           145  27.257240           266  19.042189
#
#       RankDefFT   Def2PtFG  RankDef2PtFG   Def3PtFG  RankDef3PtFG    Tempo  \
# 141         257  54.087494            73  29.562528           240  69.2574
# 288         248  48.443337           222  33.623910           101  72.5366
# 535         154  48.060837           271  32.509506            92  73.9155
# 679         131  49.097121           218  31.332357           153  68.4704
# 705         147  52.494577           121  28.893709           239  66.7883
# 1012        123  52.907640           103  28.050171           265  70.0251
#
#       RankTempo  AdjTempo  RankAdjTempo       OE  RankOE    AdjOE  RankAdjOE  \
# 141         105   67.4665           150  114.128       9  120.001          5
# 288          22   70.4937            38  119.285       9  124.727          3
# 535           8   72.6918            12  118.948       5  122.180          7
# 679         212   67.6714           215  108.022      37  112.665         24
# 705         238   65.7815           256  110.982      26  116.198         17
# 1012        132   68.0633           181   99.738     198  108.047         84
#
#             DE  RankDE     AdjDE  RankAdjDE    AdjEM  RankAdjEM     FG2Pct  \
# 141    95.9264      41   94.2785         36  25.7224          6  53.511053
# 288   105.1290     167  102.1020         89  22.6250         22  56.504599
# 535   106.3600     217  102.8870        109  19.2927         23  54.654655
# 679    96.1866      70   95.0609         52  17.6045         29  50.434783
# 705   100.9180     114   98.7991         68  17.3987         27  50.000000
# 1012   99.3547     113   93.0778         35  14.9687         49  45.500000
#
#       RankFG2Pct     FG3Pct  RankFG3Pct      FTPct  RankFTPct   BlockPct  \
# 141           45  34.731544         101  72.575251        149  11.119691
# 288           26  37.676056          33  72.466960        172  12.734584
# 535           32  40.875000           1  77.195686         24  16.184519
# 679          126  34.279476         115  79.658606          1  13.636364
# 705          195  34.747145         137  70.597243        228  10.048232
# 1012         312  33.613445         172  72.888016        102  14.859438
#
#       RankBlockPct  OppFG2Pct  RankOppFG2Pct  OppFG3Pct  RankOppFG3Pct  \
# 141             69  47.258687             73  30.843707             41
# 288             45  52.144772            231  29.702970             22
# 535              1  49.413604            135  33.216783            135
# 679             18  44.830660             25  30.703013             51
# 705            103  48.633441            100  32.408759             86
# 1012             4  46.586345             56  31.238095             49
#
#        OppFTPct  RankOppFTPct  OppBlockPct  RankOppBlockPct    FG3Rate  \
# 141   72.124756           198     6.501951               16  27.928772
# 288   70.761671           126     8.147175               84  42.738901
# 535   71.468531           147     8.708709              133  37.523452
# 679   68.782161            75     7.747036               81  26.581544
# 705   74.350087           305     5.237430                2  29.975550
# 1012  74.057650           301     9.100000              206  32.249322
#
#       RankFG3Rate  OppFG3Rate  RankOppFG3Rate      ARate  RankARate  \
# 141           351   35.827552             114  53.398058        109
# 288            93   44.822485             331  57.763975         58
# 535           179   40.149743             284  54.881517         75
# 679           350   38.317757             202  52.201258        166
# 705           330   35.510627             127  55.113025         69
# 1012          292   34.516765              86  50.894309        196
#
#        OppARate  RankOppARate   StlRate  RankStlRate  OppStlRate  \
# 141   46.826347            77  0.097813          129    0.086008
# 288   47.100176            69  0.089456          240    0.080967
# 535   52.235551           226  0.100570          114    0.085565
# 679   46.722455            66  0.075739          290    0.072466
# 705   48.367594           114  0.095732          142    0.089613
# 1012  49.044586           112  0.088876          191    0.087178
#
#       RankOppStlRate  DFP    NSTRate  RankNSTRate  OppNSTRate  RankOppNSTRate  \
# 141               94  NaN   8.052743         77.0    7.715456           307.0
# 288               30  NaN   6.529599         57.0    5.027792           364.0
# 535               92  NaN   5.717877         11.0    5.798982           354.0
# 679               22  NaN  10.846570        275.0    9.771264           180.0
# 705              156  NaN   8.524124        140.0    6.994153           352.0
# 1012     276.0   8.29     157.0     26.28         152.0  24.50     130.0
#
#        SFDR  RankSFDR   SGDR  RankSGDR   PGDR  RankPGDR  Net Rating  \
# 141   10.79     356.0  11.62     341.0  11.60     302.0        25.7
# 288   16.61     270.0  16.01     187.0  12.57     266.0        22.6
# 535   16.55     273.0  13.42     311.0  19.59      25.0        19.3
# 679   17.20     231.0  17.42     126.0  17.72      52.0        17.6
# 705   17.89     229.0  13.01     318.0   8.68     359.0        17.4
# 1012  21.83      85.0  14.46     243.0  12.90     234.0        14.9
#
#       Net Rating Rank         Mapped Conference Name Mapped ESPN Team Name  \
# 141               141  Southeastern Conference (SEC)              Kentucky
# 288               286  Southeastern Conference (SEC)              Kentucky
# 535               534  Southeastern Conference (SEC)              Kentucky
# 679               677  Southeastern Conference (SEC)              Kentucky
# 705               702  Southeastern Conference (SEC)              Kentucky
# 1012             1013  Southeastern Conference (SEC)              Kentucky
#
#      Current Coach     Full Team Name     Since Active Coaching Length  \
# 141      Mark Pope  Kentucky Wildcats  202425.0                0 years
# 288      Mark Pope  Kentucky Wildcats  202425.0                0 years
# 535      Mark Pope  Kentucky Wildcats  202425.0                0 years
# 679      Mark Pope  Kentucky Wildcats  202425.0                0 years
# 705      Mark Pope  Kentucky Wildcats  202425.0                0 years
# 1012     Mark Pope  Kentucky Wildcats  202425.0                0 years
#
#       Active Coaching Length Index                             Seed  \
# 141                            1.0  Not In a Post-Season Tournament
# 288                            1.0  Not In a Post-Season Tournament
# 535                            1.0                                3
# 679                            1.0  Not In a Post-Season Tournament
# 705                            1.0  Not In a Post-Season Tournament
# 1012                           1.0  Not In a Post-Season Tournament
#
#                                Region Correct Team Name?  \
# 141   Not In a Post-Season Tournament                NaN
# 288   Not In a Post-Season Tournament                NaN
# 535                             South           Kentucky
# 679   Not In a Post-Season Tournament                NaN
# 705   Not In a Post-Season Tournament                NaN
# 1012  Not In a Post-Season Tournament                NaN
#
#                Post-Season Tournament  Post-Season Tournament Sorting Index
# 141   Not In a Post-Season Tournament                                     5
# 288   Not In a Post-Season Tournament                                     5
# 535                     March Madness                                     1
# 679   Not In a Post-Season Tournament                                     5
# 705   Not In a Post-Season Tournament                                     5
# 1012  Not In a Post-Season Tournament                                     5

# %% [markdown]
# # Bringing in Ollama to figure out how to shape this model

# %%
def create_analysis_prompt(df_slice):
    # First get basic statistics and info about the data
    column_info = df_slice.dtypes.to_dict()
    sample_size = len(df_slice)
    
    prompt = f"""
    Analyze this college basketball dataset for Kentucky (2020-present) to recommend a machine learning model structure.
    
    Dataset Overview:
    - Number of records: {sample_size}
    - Features available: {', '.join(df_slice.columns.tolist())}
    
    Data Sample:
    {df_slice.head(3).to_string()}
    
    Column Data Types:
    {pd.Series(column_info).to_string()}
    
    Statistical Summary:
    {df_slice.describe().to_string()}
    
    Based on this data:
    1. What type of machine learning model would be most appropriate?
    2. Which features appear most relevant for prediction?
    3. What data preprocessing steps would you recommend?
    4. Are there any potential issues with the data that need addressing?
    5. What evaluation metrics would be most appropriate for this basketball data?
    """
    
    return prompt

# Generate the prompt with your data slice
analysis_prompt = create_analysis_prompt(march_madness[(march_madness['Mapped ESPN Team Name']=='Kentucky') & 
                                                      (march_madness['Season'] >=2020)])


print(analysis_prompt)
# Out:
#     Analyze this college basketball dataset for Kentucky (2020-present) to recommend a machine learning model structure.
#
#     Dataset Overview:
#     - Number of records: 6
#     - Features available: Season, Short Conference Name, Adjusted Temo, Adjusted Tempo Rank, Raw Tempo, Raw Tempo Rank, Adjusted Offensive Efficiency, Adjusted Offensive Efficiency Rank, Raw Offensive Efficiency, Raw Offensive Efficiency Rank, Adjusted Defensive Efficiency, Adjusted Defensive Efficiency Rank, Raw Defensive Efficiency, Raw Defensive Efficiency Rank, Avg Possession Length (Offense), Avg Possession Length (Offense) Rank, Avg Possession Length (Defense), Avg Possession Length (Defense) Rank, eFGPct, RankeFGPct, TOPct, RankTOPct, ORPct, RankORPct, FTRate, RankFTRate, OffFT, RankOffFT, Off2PtFG, RankOff2PtFG, Off3PtFG, RankOff3PtFG, DefFT, RankDefFT, Def2PtFG, RankDef2PtFG, Def3PtFG, RankDef3PtFG, Tempo, RankTempo, AdjTempo, RankAdjTempo, OE, RankOE, AdjOE, RankAdjOE, DE, RankDE, AdjDE, RankAdjDE, AdjEM, RankAdjEM, FG2Pct, RankFG2Pct, FG3Pct, RankFG3Pct, FTPct, RankFTPct, BlockPct, RankBlockPct, OppFG2Pct, RankOppFG2Pct, OppFG3Pct, RankOppFG3Pct, OppFTPct, RankOppFTPct, OppBlockPct, RankOppBlockPct, FG3Rate, RankFG3Rate, OppFG3Rate, RankOppFG3Rate, ARate, RankARate, OppARate, RankOppARate, StlRate, RankStlRate, OppStlRate, RankOppStlRate, DFP, NSTRate, RankNSTRate, OppNSTRate, RankOppNSTRate, AvgHeight, RankAvgHeight, CenterHeight, RankCenterHeight, PFHeight, RankPFHeight, SFHeight, RankSFHeight, SGHeight, RankSGHeight, PGHeight, RankPGHeight, EffectiveHeight, RankEffectiveHeight, Experience, RankExperience, Bench, BenchRank, CenterPts, RankCenterPts, PFPts, RankPFPts, SFPts, RankSFPts, SGPts, RankSGPts, PGPts, RankPGPts, CenterOR, RankCenterOR, PFOR, RankPFOR, SFOR, RankSFOR, SGOR, RankSGOR, PGOR, RankPGOR, CenterDR, RankCenterDR, PFDR, RankPFDR, SFDR, RankSFDR, SGDR, RankSGDR, PGDR, RankPGDR, Net Rating, Net Rating Rank, Mapped Conference Name, Mapped ESPN Team Name, Current Coach, Full Team Name, Since, Active Coaching Length, Active Coaching Length Index, Seed, Region, Correct Team Name?, Post-Season Tournament, Post-Season Tournament Sorting Index
#
#     Data Sample:
# Raw Defensive Efficiency                float64
# Raw Defensive Efficiency Rank             int64
# Avg Possession Length (Offense)         float64
# Avg Possession Length (Offense) Rank    float64
# Avg Possession Length (Defense)         float64
# Avg Possession Length (Defense) Rank    float64
# eFGPct                                  float64
# RankeFGPct                                int64
# TOPct                                   float64
# RankTOPct                                 int64
# ORPct                                   float64
# RankORPct                                 int64
# FTRate                                  float64
# RankFTRate                                int64
# OffFT                                   float64
# RankOffFT                                 int64
# Off2PtFG                                float64
# RankOff2PtFG                              int64
# Off3PtFG                                float64
# RankOff3PtFG                              int64
# DefFT                                   float64
# RankDefFT                                 int64
# Def2PtFG                                float64
# RankDef2PtFG                              int64
# Def3PtFG                                float64
# RankDef3PtFG                              int64
# Tempo                                   float64
# RankTempo                                 int64
# AdjTempo                                float64
# RankAdjTempo                              int64
# OE                                      float64
# RankOE                                    int64
# AdjOE                                   float64
# RankAdjOE                                 int64
# DE                                      float64
# RankDE                                    int64
# AdjDE                                   float64
# RankAdjDE                                 int64
# AdjEM                                   float64
# RankAdjEM                                 int64
# FG2Pct                                  float64
# RankFG2Pct                                int64
# FG3Pct                                  float64
# RankFG3Pct                                int64
# FTPct                                   float64
# RankFTPct                                 int64
# BlockPct                                float64
# RankBlockPct                              int64
# OppFG2Pct                               float64
# RankOppFG2Pct                             int64
# OppFG3Pct                               float64
# RankOppFG3Pct                             int64
# OppFTPct                                float64
# RankOppFTPct                              int64
# OppBlockPct                             float64
# RankOppBlockPct                           int64
# FG3Rate                                 float64
# RankFG3Rate                               int64
# OppFG3Rate                              float64
# RankOppFG3Rate                            int64
# ARate                                   float64
# RankARate                                 int64
# OppARate                                float64
# RankOppARate                              int64
# StlRate                                 float64
# RankStlRate                               int64
# OppStlRate                              float64
# RankOppStlRate                            int64
# DFP                                     float64
# NSTRate                                 float64
# RankNSTRate                             float64
# OppNSTRate                              float64
# RankOppNSTRate                          float64
# AvgHeight                               float64
# RankAvgHeight                           float64
# CenterHeight                            float64
# RankCenterHeight                        float64
# PFHeight                                float64
# RankPFHeight                            float64
# SFHeight                                float64
# RankSFHeight                            float64
# SGHeight                                float64
# RankSGHeight                            float64
# PGHeight                                float64
# RankPGHeight                            float64
# EffectiveHeight                         float64
# RankEffectiveHeight                     float64
# Experience                              float64
# RankExperience                          float64
# Bench                                   float64
# BenchRank                               float64
# CenterPts                               float64
# RankCenterPts                           float64
# PFPts                                   float64
# RankPFPts                               float64
# SFPts                                   float64
# RankSFPts                               float64
# SGPts                                   float64
# RankSGPts                               float64
# PGPts                                   float64
# RankPGPts                               float64
# CenterOR                                float64
# RankCenterOR                            float64
# PFOR                                    float64
# RankPFOR                                float64
# SFOR                                    float64
# RankSFOR                                float64
# SGOR                                    float64
# RankSGOR                                float64
# PGOR                                    float64
# RankPGOR                                float64
# CenterDR                                float64
# RankCenterDR                            float64
# PFDR                                    float64
# RankPFDR                                float64
# SFDR                                    float64
# RankSFDR                                float64
# SGDR                                    float64
# RankSGDR                                float64
# PGDR                                    float64
# RankPGDR                                float64
# Net Rating                              float64
# Net Rating Rank                           int64
# Mapped Conference Name                   object
# Mapped ESPN Team Name                    object
# Current Coach                            object
# Full Team Name                           object
# Since                                   float64
# Active Coaching Length                   object
# Active Coaching Length Index            float64
# Seed                                     object
# Region                                   object
# Correct Team Name?                       object
# Post-Season Tournament                   object
# Post-Season Tournament Sorting Index      int64
#
#     Statistical Summary:
#                 Season  Adjusted Temo  Adjusted Tempo Rank  Raw Tempo  Raw Tempo Rank  Adjusted Offensive Efficiency  Adjusted Offensive Efficiency Rank  Raw Offensive Efficiency  Raw Offensive Efficiency Rank  Adjusted Defensive Efficiency  Adjusted Defensive Efficiency Rank  Raw Defensive Efficiency  Raw Defensive Efficiency Rank  Avg Possession Length (Offense)  Avg Possession Length (Offense) Rank  Avg Possession Length (Defense)  Avg Possession Length (Defense) Rank     eFGPct  RankeFGPct      TOPct   RankTOPct      ORPct   RankORPct     FTRate  RankFTRate      OffFT   RankOffFT   Off2PtFG  RankOff2PtFG   Off3PtFG  RankOff3PtFG      DefFT   RankDefFT   Def2PtFG  RankDef2PtFG   Def3PtFG  RankDef3PtFG      Tempo   RankTempo   AdjTempo  RankAdjTempo          OE      RankOE       AdjOE  RankAdjOE          DE      RankDE       AdjDE   RankAdjDE      AdjEM  RankAdjEM     FG2Pct  RankFG2Pct     FG3Pct  RankFG3Pct      FTPct   RankFTPct   BlockPct  RankBlockPct  OppFG2Pct  RankOppFG2Pct  OppFG3Pct  RankOppFG3Pct   OppFTPct  RankOppFTPct  OppBlockPct  RankOppBlockPct    FG3Rate  RankFG3Rate  OppFG3Rate  RankOppFG3Rate      ARate   RankARate   OppARate  RankOppARate   StlRate  RankStlRate  OppStlRate  RankOppStlRate  DFP    NSTRate  RankNSTRate  OppNSTRate  RankOppNSTRate  AvgHeight  RankAvgHeight  CenterHeight  RankCenterHeight  PFHeight  RankPFHeight  SFHeight  RankSFHeight  SGHeight  RankSGHeight  PGHeight  RankPGHeight  EffectiveHeight  RankEffectiveHeight  Experience  RankExperience      Bench   BenchRank  CenterPts  RankCenterPts      PFPts   RankPFPts      SFPts   RankSFPts      SGPts   RankSGPts      PGPts   RankPGPts   CenterOR  RankCenterOR       PFOR    RankPFOR       SFOR    RankSFOR       SGOR    RankSGOR       PGOR    RankPGOR   CenterDR  RankCenterDR       PFDR    RankPFDR       SFDR    RankSFDR       SGDR    RankSGDR       PGDR    RankPGDR  Net Rating  Net Rating Rank     Since  Active Coaching Length Index  Post-Season Tournament Sorting Index
# count     6.000000       6.000000             6.000000   6.000000        6.000000                       6.000000                            6.000000                  6.000000                       6.000000                       6.000000                            6.000000                   6.00000                       6.000000                         6.000000                              6.000000                         6.000000                              6.000000   6.000000    6.000000   6.000000    6.000000   6.000000    6.000000   6.000000    6.000000   6.000000    6.000000   6.000000      6.000000   6.000000      6.000000   6.000000    6.000000   6.000000      6.000000   6.000000      6.000000   6.000000    6.000000   6.000000      6.000000    6.000000    6.000000    6.000000   6.000000    6.000000    6.000000    6.000000    6.000000   6.000000   6.000000   6.000000    6.000000   6.000000    6.000000   6.000000    6.000000   6.000
# max    2025.000000      72.700000           256.000000  73.900000      238.000000                     124.700000                           84.000000                119.300000                     198.000000                     102.900000                          109.000000                 106.40000                     217.000000                        17.600000                            183.000000                        18.100000                            299.000000  57.152908  289.000000  19.756581  217.000000  39.202658  174.000000  40.800929  248.000000  24.273949  281.000000  60.940392    258.000000  35.062807    350.000000  19.570522  257.000000  54.087494    271.000000  33.623910    265.000000  73.915500  238.000000  72.691800    256.000000  119.285000  198.000000  124.727000  84.000000  106.360000  217.000000  102.887000  109.000000  25.722400  49.000000  56.504599  312.000000  40.875000  172.000000  79.658606  228.000000  16.184519    103.000000  52.144772     231.000000  33.216783     135.000000  74.350087    305.000000     9.100000       206.000000  42.738901   351.000000   44.822485      331.000000  57.763975  196.000000  52.235551    226.000000  0.100570   290.000000    0.089613      156.000000  NaN  11.038777   275.000000    9.771264      364.000000  78.950000     188.000000      2.340000        192.000000  1.950000     50.000000  2.130000     194.00000  1.610000    174.000000  2.410000    322.000000         2.060000           105.000000    3.196470      335.000000  36.550000  281.000000  24.020000     332.000000  24.840000  331.000000  25.120000  249.000000  22.610000  273.000000  22.340000  338.000000  41.210000    349.000000  51.550000  211.000000  25.120000  352.000000  13.000000  342.000000  15.560000  342.000000  32.950000    269.000000  35.880000  256.000000  21.830000  356.000000  17.420000  341.000000  19.590000  359.000000   25.700000      1013.000000  202425.0                           1.0                              5.000000
#
#     Based on this data:
#     1. What type of machine learning model would be most appropriate?
#     2. Which features appear most relevant for prediction?
#     3. What data preprocessing steps would you recommend?
#     4. Are there any potential issues with the data that need addressing?
#     5. What evaluation metrics would be most appropriate for this basketball data?

# %%
stream_function(analysis_prompt)
# Out:
# Here are the answers to your questions:
#
# **1. What type of machine learning model would be most appropriate?**
#
# Based on the provided data, a logistic regression or decision tree model seems like a good fit. The data appears to be a classification problem with multiple features and target variable (number of points scored in a game). Logistic regression is suitable for multi-class classification problems, while decision trees can handle both categorical and continuous features.
#
# **2. Which features appear most relevant for prediction?**
#
# After examining the feature names, I would say that the following three features are most relevant:
#
# * `points`: This feature has a strong relationship with the target variable (number of points scored in a game).
# * `turns`: This feature also appears to be related to the target variable, although its significance is not as clear.
# * `fg%`: This feature suggests that shot percentage might be an important factor in predicting scores.
#
# **3. What data preprocessing steps would you recommend?**
#
# To prepare the data for analysis, I would suggest the following:
#
# * **Standardize features**: Perform standardization to ensure all features are on the same scale and to avoid non-linear relationships.
# * **Handle missing values**: Consider imputing missing values or removing rows with missing values (if possible).
# * **Check for normalization**: If the data has a fixed range, it's worth checking if any feature is out of bounds.
#
# **4. Are there any potential issues with the data that need addressing?**
#
# The following issues arise:
#
# * **Data integrity**: There are multiple instances where players have been played against each other twice (e.g., player A vs. player B). This might lead to biased results.
# * **Overfitting**: The number of features is increasing rapidly, which may cause overfitting to the training data.
# * **Feature selection**: It's unclear what specific features are most important for predicting points scored.
#
# **5. What evaluation metrics would be most appropriate for this basketball data?**
#
# Given that we're trying to predict points scored in a game, some common evaluation metrics include:
#
# * Mean Absolute Error (MAE)
# * Root Mean Squared Percentage Error (RMSPE)
# * Mean Absolute Difference (MAD)
#
# These metrics provide insight into the accuracy of our predictions and can help us identify which features are most important.
